# %%
# %env ANYWIDGET_HMR=1
# %load_ext autoreload
# %autoreload 2
# Out:
# env: ANYWIDGET_HMR=1
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from tldraw import StrokeWidget

s = StrokeWidget(width=900, height=440)

def on_stroke(change):
    pts = s.stroke
    print(f"got stroke with {len(pts)} points; first 3: {pts[:3]}")

s.observe(on_stroke, names=['stroke'])
s

# %%
s.stroke
# Out:
# [[100.82421875, 185.18359375],
#  [101.818267578125, 183.30949609375],
#  [103.662905140625, 180.62540884375],
#  [107.042575474625, 176.84964037974999],
#  [109.514795823821, 174.006528585334],
#  [112.53762119378362, 170.7774851441717],
#  [115.81010069504329, 167.5433386371794],
#  [120.11614204372856, 163.4719004373756],
#  [123.99495666241333, 160.17136618168232],
#  [126.84825837747785, 157.9290044528352],
#  [130.30282951047295, 155.91561279734233],
#  [135.3883662068223, 154.45561679925424],
#  [140.06974191963633, 153.66137897629432],
#  [143.56492593240716, 153.3843936787291],
#  [147.1629466603545, 153.53919805185365],
#  [151.01730118635783, 154.41250538083338],
#  [155.48135129850368, 156.06855331779835],
#  [160.189794559511, 158.53338089550732],
#  [164.80318769349898, 161.10509084778099],
#  [170.29468605838844, 164.84288231181785],
#  [175.5299986688883, 168.59960024325392],
#  [181.61097747900024, 173.47900479795513],
#  [185.98154557670114, 177.1959165007126],
# ...
