# %%
from tldraw import TldrawMakeStaticTldraw

TldrawMakeStaticTldraw(width=402)

# %%
from tldraw import TldrawMakeStaticPNG

TldrawMakeStaticPNG(width=402)

# %%
from tldraw import TldrawMakeStaticSVG

TldrawMakeStaticSVG(width=402)

# %%
from tldraw import TldrawMakeStaticToMarkdown

TldrawMakeStaticToMarkdown(width=402)
