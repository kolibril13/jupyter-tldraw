# %%
my_prompt =  """
Hello!

Please return this python script for me, but make 3 adjustments:
1. Change the text to the text that you see in the image. Seperate a new line by using \n
2. Change the text color to the color that you see in the image.
2. Change the background color to the color that you see in the image.

```
import sys
sys.path.append('/Library/Application Support/Blackmagic Design/DaVinci Resolve/Developer/Scripting/Modules')
import DaVinciResolveScript as dvr_script

resolve = dvr_script.scriptapp("Resolve")

projectManager = resolve.GetProjectManager()
currentProject = projectManager.GetCurrentProject()
media_pool = currentProject.GetMediaPool()

currentTimeline = currentProject.GetCurrentTimeline()
if currentTimeline is None:
    currentTimeline = media_pool.CreateEmptyTimeline("MyTimeLine")

print(f"Current project: {currentProject.GetName()}")


# Insert Fusion Composition into the timeline
obj = currentTimeline.InsertFusionCompositionIntoTimeline()
fusion_comp = obj.AddFusionComp()

# Add TextPlus tool and set initial text
text_tool = fusion_comp.AddTool("TextPlus")
text_tool.SetInput("StyledText", "Hello\nWorld") #adjust

#for the text
text_tool.SetInput("Red1", 0) #adjust
text_tool.SetInput("Green1", 0) #adjust
text_tool.SetInput("Blue1", 1) #adjust
text_tool.SetInput("Alpha1", 1)

#for the background
text_tool.SetInput("Red", 0) #adjust
text_tool.SetInput("Green", 1) #adjust
text_tool.SetInput("Blue", 1) #adjust
text_tool.SetInput("Alpha", 1) #adjust

# Set the text size to 0.3
text_tool.SetInput("Size", 0.2)
text_tool.SetInput("Font", "Comic Sans MS")

# Connect the text tool to MediaOut1
media_out_tool = fusion_comp.FindTool("MediaOut1")
media_out_tool.ConnectInput("Input", text_tool)
``` 
"""

from tldraw import MakeReal
from api_key import api_key

m = MakeReal(width=1002, height = 500, api_key = api_key , prompt = my_prompt , run_next_cell = True)
m

# %% [markdown]
# ![image.png](attachment:457517e8-60b6-4e57-9baf-2d42d7fc273e.png)

# %%
import sys
sys.path.append('/Library/Application Support/Blackmagic Design/DaVinci Resolve/Developer/Scripting/Modules')
import DaVinciResolveScript as dvr_script

resolve = dvr_script.scriptapp("Resolve")

projectManager = resolve.GetProjectManager()
currentProject = projectManager.GetCurrentProject()
media_pool = currentProject.GetMediaPool()

currentTimeline = currentProject.GetCurrentTimeline()
if currentTimeline is None:
    currentTimeline = media_pool.CreateEmptyTimeline("MyTimeLine")

print(f"Current project: {currentProject.GetName()}")


# Insert Fusion Composition into the timeline
obj = currentTimeline.InsertFusionCompositionIntoTimeline()
fusion_comp = obj.AddFusionComp()

# Add TextPlus tool and set initial text
text_tool = fusion_comp.AddTool("TextPlus")
text_tool.SetInput("StyledText", "Hello\nTldraw") #adjust

#for the text
text_tool.SetInput("Red1", 62 / 255) #adjust
text_tool.SetInput("Green1", 62 / 255) #adjust
text_tool.SetInput("Blue1", 64 / 255) #adjust
text_tool.SetInput("Alpha1", 1)

#for the background
text_tool.SetInput("Red", 255 / 255) #adjust
text_tool.SetInput("Green", 204 / 255) #adjust
text_tool.SetInput("Blue", 0 / 255) #adjust
text_tool.SetInput("Alpha", 1) #adjust

# Set the text size to 0.3
text_tool.SetInput("Size", 0.2)
text_tool.SetInput("Font", "Comic Sans MS")

# Connect the text tool to MediaOut1
media_out_tool = fusion_comp.FindTool("MediaOut1")
media_out_tool.ConnectInput("Input", text_tool)

# %% [markdown]
# ![image.png](attachment:f485a63f-a9d0-41b3-b9c8-eaec38da8e88.png)
