# %%
from tldraw import MakeReal
from api_key import api_key

data = {
    "banana" : 12,
    "apple" : 10,
    "orange": 2,
}

custom_prompt =  f"""
Make a plot using the following data:
{data}
Use the matplotlib module
In the providied image, you will see some instructions how the plot should look like. 
Follow them to the best of your abilities.

Reply ONLY with python code.
"""

m = MakeReal(width=450, height = 400, api_key = api_key, prompt = custom_prompt)
m
# Out:
# MakeReal Widget

# %%
import matplotlib.pyplot as plt

# Data to plot
data = {'banana': 12, 'apple': 10, 'orange': 2}
fruits = list(data.keys())
quantities = list(data.values())

# Plot
fig, ax = plt.subplots()
ax.pie(quantities, labels=fruits, autopct='%1.1f%%', startangle=90)
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
