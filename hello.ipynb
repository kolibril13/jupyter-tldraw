# %%
from tldraw import TldrawWidget
q = TldrawWidget(content="Hello World")

# %%
q
# Out:
# Tldraw1(content='Hello World')

# %%
q.content = "Joho!"

# %%
import tldraw1

tldraw1.__version__
# Out:
# '0.0.0'
